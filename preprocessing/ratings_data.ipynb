# %%
import pandas as pd

# %%
ratings_df = pd.read_csv('../datasets/ratings.csv')

# %%
ratings_df
# Out:
#           userId  movieId  rating   timestamp
# 0              1      169     2.5  1204927694
# 1              1     2471     3.0  1204927438
# 2              1    48516     5.0  1204927435
# 3              2     2571     3.5  1436165433
# 4              2   109487     4.0  1436165496
# ...          ...      ...     ...         ...
# 22884372  247753    49530     5.0  1430437962
# 22884373  247753    69481     3.0  1430437984
# 22884374  247753    74458     4.0  1430437968
# 22884375  247753    76093     5.0  1430437811
# 22884376  247753   130636     0.5  1430437721
#
# [22884377 rows x 4 columns]

# %%
ratings_df = ratings_df.drop(columns='timestamp') # drop 'timestamp' column to save memory (not going to use it)

ratings_df
# Out:
#           userId  movieId  rating
# 0              1      169     2.5
# 1              1     2471     3.0
# 2              1    48516     5.0
# 3              2     2571     3.5
# 4              2   109487     4.0
# ...          ...      ...     ...
# 22884372  247753    49530     5.0
# 22884373  247753    69481     3.0
# 22884374  247753    74458     4.0
# 22884375  247753    76093     5.0
# 22884376  247753   130636     0.5
#
# [22884377 rows x 3 columns]

# %%
ratings_df.to_csv("../datasets/ratings_data.csv", index=False)
